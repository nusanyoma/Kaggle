# %% [markdown]
# ## Divide and Conquer
# This notebook is to explore features and optimize models for each site_id. The idea is to resolve some data discrepancies that are present by dividing the data rather than cleaning.
#
# Note that this is just another approach, need not necessarily be better or worse, but probably can add some value to ensembles irrespective of its CV or public LB scores.

# %%
import gc
import os

import lightgbm as lgb
import numpy as np
import pandas as pd

from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold, TimeSeriesSplit
from sklearn.preprocessing import LabelEncoder

from tqdm.notebook import tqdm
import datetime
import warnings
warnings.filterwarnings('ignore')

path_data = "./ashrae-energy-prediction/"
path_train = path_data + "train.csv"
path_test = path_data + "test.csv"
path_building = path_data + "building_metadata.csv"
path_weather_train = path_data + "weather_train.csv"
path_weather_test = path_data + "weather_test.csv"

myfavouritenumber = 38
seed = myfavouritenumber

# %% [markdown]
# ## Preparing data
# There are two files with features that need to be merged with the data. One is building metadata that has information on the buildings and the other is weather data that has information on the weather.

# %%
## Memory Optimization

# Original code from https://www.kaggle.com/gemartin/load-data-reduce-memory-usage by @gemartin
# Modified to support timestamp type, categorical type
# Modified to add option to use float16

from pandas.api.types import is_datetime64_any_dtype as is_datetime
from pandas.api.types import is_categorical_dtype

def reduce_mem_usage(df, use_float16=False):
    """
    Iterate through all the columns of a dataframe and modify the data type to reduce memory usage.        
    """
    
    start_mem = df.memory_usage().sum() / 1024**2
    print("Memory usage of dataframe is {:.2f} MB".format(start_mem))
    
    for col in df.columns:
        if is_datetime(df[col]) or is_categorical_dtype(df[col]):
            continue
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == "int":
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if use_float16 and c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype("category")

    end_mem = df.memory_usage().sum() / 1024**2
    print("Memory usage after optimization is: {:.2f} MB".format(end_mem))
    print("Decreased by {:.1f}%".format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
def target_encoding()

# %%
df_train.groupby(['meter', 'primary_use'])['meter_reading'].agg(['count', 'mean', 'median']).reset_index()
# Out:
#     meter                    primary_use    count          mean      median
# 0       0                      Education  4499129    250.736974    97.72120
# 1       0  Entertainment/public assembly  1494423    117.497227    32.20000
# 2       0         Food sales and service    43826     94.794985    72.00000
# 3       0                     Healthcare   184345    297.179204   164.77100
# 4       0            Lodging/residential  1137714    117.234521    66.05000
# 5       0       Manufacturing/industrial    85216     90.659198    52.05900
# 6       0                         Office  2230893    163.042765    68.00000
# 7       0                          Other   195256     74.837913    13.20000
# 8       0                        Parking   160375     68.409131    54.01000
# 9       0                Public services  1320045     98.712629    36.74000
# 10      0              Religious worship    25034      4.592755     3.75000
# 11      0                         Retail    76315    175.016276    42.89500
# 12      0                       Services    78951     92.203716    71.11800
# 13      0             Technology/science    45275    107.892623   102.00200
# 14      0                        Utility    32476    169.304692    59.65125
# 15      0              Warehouse/storage   103077     51.562507    21.41400
# 16      1                      Education  1823125    736.632588   173.76800
# 17      1  Entertainment/public assembly   371663   1526.434522   147.56700
# 18      1         Food sales and service    35132    372.636543   147.00400
# 19      1                     Healthcare   111324    869.034419   199.57150
# 20      1            Lodging/residential   457833    417.783481   113.75100
# 21      1       Manufacturing/industrial     6677    301.235984   217.69300
# 22      1                         Office  1117099    283.246515    60.97560
# 23      1                          Other    22674    733.031598    83.89610
# 24      1                        Parking     8781     10.233911     5.72690
# 25      1                Public services   179877    476.721950   198.77200
# 26      1              Religious worship     7327      8.051416     5.54730
# 27      1                         Retail    16039    146.403762    72.48230
# 28      1             Technology/science    16106    138.134888    70.12355
# 29      1                        Utility     8783   1375.784961  1080.41000
# 30      2                      Education  1136519  30607.160189   217.06100
# 31      2  Entertainment/public assembly   242771    615.157744   228.75000
# 32      2         Food sales and service    17568    911.671646   742.47400
# 33      2                     Healthcare    77513   1726.272072   950.10500
# 34      2            Lodging/residential   363648    742.800104   125.23500
# 35      2       Manufacturing/industrial    33820    774.807903   511.71900
# 36      2                         Office   677872   2305.234128   399.41400
# 37      2                          Other     8784    267.810476   117.18750
# 38      2                        Parking    17568   1431.267259   594.00000
# 39      2                Public services    83882   2728.422804   536.11050
# 40      2                       Services    17568  22185.124643   387.20700
# 41      2             Technology/science     7472    132.241012   110.71200
# 42      2                        Utility    14944    751.839621   590.90200
# 43      2              Warehouse/storage     8784     87.217012     7.08010
# 44      3                      Education   608604    300.172583    26.24810
# 45      3  Entertainment/public assembly   139188   1300.618987    50.23200
# 46      3         Food sales and service    17564     86.811446    26.37640
# 47      3                     Healthcare    25345    355.678200   109.39000
# 48      3            Lodging/residential    95850     57.460218    35.78120
# 49      3                         Office   289690    245.048437    79.12920
# 50      3                Public services    79022    434.909215   163.18100
# 51      3             Technology/science     8774    299.821983     0.00000

# %%
df_train = pd.read_csv(path_train)
df_test = pd.read_csv(path_test)

building = pd.read_csv(path_building)
le = LabelEncoder()
# primary_useのLabelEncoding→あとでTargetEncodingに
building.primary_use = le.fit_transform(building.primary_use)
#building['age'] = building['year_built'].max() - building['year_built'] + 1

weather_train = pd.read_csv(path_weather_train)
weather_test = pd.read_csv(path_weather_test)

# これらの特徴量は使わない
weather_train.drop(["sea_level_pressure", "wind_direction", "wind_speed"], axis=1, inplace=True)
weather_test.drop(["sea_level_pressure", "wind_direction", "wind_speed"], axis=1, inplace=True)

# site_idでgroup_by、interpolation補間
weather_train = weather_train.groupby("site_id").apply(lambda group: group.interpolate(limit_direction="both"))
weather_test = weather_test.groupby("site_id").apply(lambda group: group.interpolate(limit_direction="both"))

# trainとbuilding_metadataをmerge
df_train = df_train.merge(building, on="building_id")
# さらにweather_trainをmerge
df_train = df_train.merge(weather_train, on=["site_id", "timestamp"], how="left")
# 多分外れ値除去
df_train = df_train[~((df_train.site_id==0) & (df_train.meter==0) & (df_train.building_id <= 104) & (df_train.timestamp < "2016-05-21"))]
df_train.reset_index(drop=True, inplace=True)
# datetime型に変換
df_train.timestamp = pd.to_datetime(df_train.timestamp, format='%Y-%m-%d %H:%M:%S')
# targetをlog変換
df_train["log_meter_reading"] = np.log1p(df_train.meter_reading)

# testとbuilding_metadataをmerge
df_test = df_test.merge(building, on="building_id")
# さらにweather_testをmerge
df_test = df_test.merge(weather_test, on=["site_id", "timestamp"], how="left")
df_test.reset_index(drop=True, inplace=True)
# datetime型に
df_test.timestamp = pd.to_datetime(df_test.timestamp, format='%Y-%m-%d %H:%M:%S')

del building, le
gc.collect()
# Out:
# 0

# %%
df_train = reduce_mem_usage(df_train, use_float16=True)
df_test = reduce_mem_usage(df_test, use_float16=True)

# weatherのほうもdatetime型に変換
weather_train.timestamp = pd.to_datetime(weather_train.timestamp, format='%Y-%m-%d %H:%M:%S')
weather_test.timestamp = pd.to_datetime(weather_test.timestamp, format='%Y-%m-%d %H:%M:%S')
weather_train = reduce_mem_usage(weather_train, use_float16=True)
weather_test = reduce_mem_usage(weather_test, use_float16=True)
# Out:
# Memory usage of dataframe is 2122.08 MB
# Memory usage after optimization is: 663.15 MB
# Decreased by 68.7%
# Memory usage of dataframe is 4135.66 MB
# Memory usage after optimization is: 1312.28 MB
# Decreased by 68.3%
# Memory usage of dataframe is 6.40 MB
# Memory usage after optimization is: 2.27 MB
# Decreased by 64.6%
# Memory usage of dataframe is 12.69 MB
# Memory usage after optimization is: 4.49 MB
# Decreased by 64.6%

# %% [markdown]
# ## Feature Engineering: Time
# Creating time-based features.

# %%
# hourと曜日 (weekday) と月を追加
df_train["hour"] = df_train.timestamp.dt.hour
df_train["weekday"] = df_train.timestamp.dt.weekday
#df_train["month"] = df_train.timestamp.dt.month

df_test["hour"] = df_test.timestamp.dt.hour
df_test["weekday"] = df_test.timestamp.dt.weekday
#df_test["month"] = df_test.timestamp.dt.month

# %% [markdown]
# ## Feature Engineering: Aggregation
# Creating aggregate features for buildings at various levels.

# %%
# 建物、meterごとにmeter_readingの平均値と中央値を追加
df_building_meter = df_train.groupby(["building_id", "meter"]).agg(mean_building_meter=("log_meter_reading", "mean"),
                                                             median_building_meter=("log_meter_reading", "median")).reset_index()

df_train = df_train.merge(df_building_meter, on=["building_id", "meter"])
df_test = df_test.merge(df_building_meter, on=["building_id", "meter"])

# 建物、meter、時間ごとにmeter_readingの平均値と中央値を追加
df_building_meter_hour = df_train.groupby(["building_id", "meter", "hour"]).agg(mean_building_meter=("log_meter_reading", "mean"),
                                                                                median_building_meter=("log_meter_reading", "median")).reset_index()

df_train = df_train.merge(df_building_meter_hour, on=["building_id", "meter", "hour"])
df_test = df_test.merge(df_building_meter_hour, on=["building_id", "meter", "hour"])

# %% [markdown]
# ## Feature Engineering: Lags
# Creating lag-based features. These are statistics of available features looking back in time by fixed intervals.
# These features are created in the weather data itself and then merged with the train and test data.

# %%
def create_lag_features(df, window):
    """
    Creating lag-based features looking back in time.
    """
    # 気温、雲の割合、湿度、降水量/hについて
    feature_cols = ["air_temperature", "cloud_coverage", "dew_temperature", "precip_depth_1_hr"]
    # site_idでgroupby
    df_site = df.groupby("site_id")
    
    # windowごとに（欠損値なしで）まとめる
    df_rolled = df_site[feature_cols].rolling(window=window, min_periods=0)
    
    # windowごとの平均値、中央値、最小値、最大値、標準偏差、歪度（分布の非対称性）
    df_mean = df_rolled.mean().reset_index().astype(np.float16)
    df_median = df_rolled.median().reset_index().astype(np.float16)
    df_min = df_rolled.min().reset_index().astype(np.float16)
    df_max = df_rolled.max().reset_index().astype(np.float16)
    df_std = df_rolled.std().reset_index().astype(np.float16)
    df_skew = df_rolled.skew().reset_index().astype(np.float16)
    
    # 各特徴量について、上記の値を追加
    for feature in feature_cols:
        df[f"{feature}_mean_lag{window}"] = df_mean[feature]
        df[f"{feature}_median_lag{window}"] = df_median[feature]
        df[f"{feature}_min_lag{window}"] = df_min[feature]
        df[f"{feature}_max_lag{window}"] = df_max[feature]
        df[f"{feature}_std_lag{window}"] = df_std[feature]
        df[f"{feature}_skew_lag{window}"] = df_std[feature]
        
    return df

# %% [markdown]
# ## Features
# Creating and selecting all the features.

# %%
weather_train = create_lag_features(weather_train, 18)
# rolling前の数値は除去
weather_train.drop(["air_temperature", "cloud_coverage", "dew_temperature", "precip_depth_1_hr"], axis=1, inplace=True)

df_train = df_train.merge(weather_train, on=["site_id", "timestamp"], how="left")

del weather_train
gc.collect()
# Out:
# 38

# %%
# categorical変数
categorical_features = [
    "building_id",
    "primary_use",
    "meter",
    "weekday",
    "hour"
]

all_features = [col for col in df_train.columns if col not in ["timestamp", "site_id", "meter_reading", "log_meter_reading"]]

# %% [markdown]
# ## KFold Cross Validation with LGBM
# Since the test data is out of time and longer than train data, creating a reliable validation strategy is going to be a major challenge. Just using a simple KFold CV here.
#
# The folds are applied to each site individually, thus building 16 sites x 3 folds = 48 models in total.

# %%
cv = 5
models = {}
cv_scores = {"(site_id, meter)": [], "cv_score": []}

for site_id in tqdm(range(16), desc="site_id"):
    for meter in range(4):
        print(cv, "fold CV for site_id:", site_id, "for meter:", meter)
        kf = TimeSeriesSplit(n_splits=cv)
        # modelを16×4個(site_id×meter分)作る
        #models[(site_id, meter)] = []

        # あるsite_id(0~15)、meter(0~3)のデータセットについて
        X_train_site = df_train[(df_train.site_id==site_id) & (df_train.meter==meter)].reset_index(drop=True)
        if X_train_site.shape[0] == 0:
            continue
        y_train_site = X_train_site.log_meter_reading
        y_pred_train_site = np.zeros(X_train_site.shape[0])
    
        score = 0

        for fold, (train_index, valid_index) in enumerate(kf.split(X_train_site, y_train_site)):
            X_train, X_valid = X_train_site.loc[train_index, all_features], X_train_site.loc[valid_index, all_features]
            y_train, y_valid = y_train_site.iloc[train_index], y_train_site.iloc[valid_index]

            dtrain = lgb.Dataset(X_train, label=y_train, categorical_feature=categorical_features)
            dvalid = lgb.Dataset(X_valid, label=y_valid, categorical_feature=categorical_features)

            watchlist = [dtrain, dvalid]

            params = {"objective": "regression",
                      "num_leaves": 41,
                      "learning_rate": 0.049,
                      "bagging_freq": 5,
                      "bagging_fraction": 0.51,
                      "feature_fraction": 0.81,
                      "metric": "rmse"
                      }

            model_lgb = lgb.train(params, train_set=dtrain, num_boost_round=1500, valid_sets=watchlist, verbose_eval=100, early_stopping_rounds=20)
            #models[(site_id, meter)].append(model_lgb)

            y_pred_valid = model_lgb.predict(X_valid, num_iteration=model_lgb.best_iteration)
            y_pred_train_site[valid_index] = y_pred_valid

            rmse = np.sqrt(mean_squared_error(y_valid, y_pred_valid))
            print("Site Id:", site_id, ", Meter:", meter, ", Fold:", fold+1, ", RMSE:", rmse)
            score += rmse / cv
        
            gc.collect()
        
        model_all = lgb.LGBMRegressor(**params, num_boost_round=int(np.floor(model_lgb.best_iteration * 1.25)))
        model_all.fit(X_train_site.loc[:, all_features], y_train_site, categorical_feature=categorical_features)
        models[(site_id, meter)] = model_all
        
        cv_scores["(site_id, meter)"].append((site_id, meter))
        cv_scores["cv_score"].append(score)
        
        print("\nSite Id:", site_id, ", Meter:", meter, ", CV RMSE:", np.sqrt(mean_squared_error(y_train_site, y_pred_train_site)), "\n")
# Out:
# HBox(children=(IntProgress(value=0, description='site_id', max=16, style=ProgressStyle(description_width='init…
# 5 fold CV for site_id: 0 for meter: 0
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [59]	training's rmse: 0.205353	valid_1's rmse: 0.305764
# Site Id: 0 , Meter: 0 , Fold: 1 , RMSE: 0.3057636874674805
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.185798	valid_1's rmse: 0.47988
# Early stopping, best iteration is:
# [135]	training's rmse: 0.174737	valid_1's rmse: 0.476438
# Site Id: 0 , Meter: 0 , Fold: 2 , RMSE: 0.4764972490205646
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [55]	training's rmse: 0.250755	valid_1's rmse: 0.525424
# Site Id: 0 , Meter: 0 , Fold: 3 , RMSE: 0.5254235646056596
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.282266	valid_1's rmse: 0.292107
# Early stopping, best iteration is:
# [114]	training's rmse: 0.27542	valid_1's rmse: 0.291734
# Site Id: 0 , Meter: 0 , Fold: 4 , RMSE: 0.2912720438468358
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [78]	training's rmse: 0.291904	valid_1's rmse: 0.452934
# Site Id: 0 , Meter: 0 , Fold: 5 , RMSE: 0.4530397598099858
#
# Site Id: 0 , Meter: 0 , CV RMSE: 2.361994239459023
#
# 5 fold CV for site_id: 0 for meter: 1
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.11818	valid_1's rmse: 1.08261
# Early stopping, best iteration is:
# [165]	training's rmse: 0.998008	valid_1's rmse: 1.07727
# Site Id: 0 , Meter: 1 , Fold: 1 , RMSE: 1.07188345403763
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [77]	training's rmse: 1.05686	valid_1's rmse: 2.17821
# Site Id: 0 , Meter: 1 , Fold: 2 , RMSE: 2.1797480184348905
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [60]	training's rmse: 1.31294	valid_1's rmse: 1.53219
# Site Id: 0 , Meter: 1 , Fold: 3 , RMSE: 1.5415248444148177
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [37]	training's rmse: 1.41839	valid_1's rmse: 1.1788
# Site Id: 0 , Meter: 1 , Fold: 4 , RMSE: 1.1801654926980671
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.18886	valid_1's rmse: 2.14481
# Early stopping, best iteration is:
# [119]	training's rmse: 1.15964	valid_1's rmse: 2.14164
# Site Id: 0 , Meter: 1 , Fold: 5 , RMSE: 2.143869720984082
#
# Site Id: 0 , Meter: 1 , CV RMSE: 3.2618089424369163
#
# 5 fold CV for site_id: 0 for meter: 2
# 5 fold CV for site_id: 0 for meter: 3
# 5 fold CV for site_id: 1 for meter: 0
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.367038	valid_1's rmse: 0.416015
# Early stopping, best iteration is:
# [155]	training's rmse: 0.323701	valid_1's rmse: 0.408972
# Site Id: 1 , Meter: 0 , Fold: 1 , RMSE: 0.4098884454767118
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [31]	training's rmse: 0.519231	valid_1's rmse: 0.535106
# Site Id: 1 , Meter: 0 , Fold: 2 , RMSE: 0.535105861231612
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.271026	valid_1's rmse: 0.303856
# Early stopping, best iteration is:
# [136]	training's rmse: 0.249027	valid_1's rmse: 0.302139
# Site Id: 1 , Meter: 0 , Fold: 3 , RMSE: 0.2992150029574988
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [66]	training's rmse: 0.292987	valid_1's rmse: 0.575991
# Site Id: 1 , Meter: 0 , Fold: 4 , RMSE: 0.5756458200912125
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [21]	training's rmse: 0.593583	valid_1's rmse: 0.595702
# Site Id: 1 , Meter: 0 , Fold: 5 , RMSE: 0.5762718329541282
#
# Site Id: 1 , Meter: 0 , CV RMSE: 2.023152711042575
#
# 5 fold CV for site_id: 1 for meter: 1
# 5 fold CV for site_id: 1 for meter: 2
# 5 fold CV for site_id: 1 for meter: 3
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.3298	valid_1's rmse: 2.07897
# Early stopping, best iteration is:
# [158]	training's rmse: 1.27466	valid_1's rmse: 2.06067
# Site Id: 1 , Meter: 3 , Fold: 1 , RMSE: 2.06066983070823
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.24549	valid_1's rmse: 1.86509
# Early stopping, best iteration is:
# [178]	training's rmse: 1.18642	valid_1's rmse: 1.85505
# Site Id: 1 , Meter: 3 , Fold: 2 , RMSE: 1.855047060048883
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.18077	valid_1's rmse: 2.67096
# Early stopping, best iteration is:
# [90]	training's rmse: 1.19401	valid_1's rmse: 2.66671
# Site Id: 1 , Meter: 3 , Fold: 3 , RMSE: 2.6861827614071943
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [37]	training's rmse: 1.34978	valid_1's rmse: 1.77965
# Site Id: 1 , Meter: 3 , Fold: 4 , RMSE: 1.7796515843445715
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.28223	valid_1's rmse: 1.33802
# Early stopping, best iteration is:
# [145]	training's rmse: 1.24695	valid_1's rmse: 1.33532
# Site Id: 1 , Meter: 3 , Fold: 5 , RMSE: 1.3353175619315303
#
# Site Id: 1 , Meter: 3 , CV RMSE: 2.002985868986168
#
# 5 fold CV for site_id: 2 for meter: 0
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.297671	valid_1's rmse: 0.512463
# Early stopping, best iteration is:
# [130]	training's rmse: 0.283132	valid_1's rmse: 0.509649
# Site Id: 2 , Meter: 0 , Fold: 1 , RMSE: 0.49879533573723817
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.316463	valid_1's rmse: 0.393162
# [200]	training's rmse: 0.277122	valid_1's rmse: 0.387627
# Early stopping, best iteration is:
# [210]	training's rmse: 0.275156	valid_1's rmse: 0.387394
# Site Id: 2 , Meter: 0 , Fold: 2 , RMSE: 0.39114273025902363
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.290257	valid_1's rmse: 0.354395
# Early stopping, best iteration is:
# [83]	training's rmse: 0.302131	valid_1's rmse: 0.353309
# Site Id: 2 , Meter: 0 , Fold: 3 , RMSE: 0.35296754452487206
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.289779	valid_1's rmse: 0.670148
# [200]	training's rmse: 0.250353	valid_1's rmse: 0.668214
# [300]	training's rmse: 0.233451	valid_1's rmse: 0.667386
# Early stopping, best iteration is:
# [302]	training's rmse: 0.233239	valid_1's rmse: 0.667308
# Site Id: 2 , Meter: 0 , Fold: 4 , RMSE: 0.6674774337966828
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.331938	valid_1's rmse: 0.491283
# [200]	training's rmse: 0.281749	valid_1's rmse: 0.486121
# [300]	training's rmse: 0.259005	valid_1's rmse: 0.484876
# [400]	training's rmse: 0.245473	valid_1's rmse: 0.484614
# Early stopping, best iteration is:
# [384]	training's rmse: 0.247902	valid_1's rmse: 0.484236
# Site Id: 2 , Meter: 0 , Fold: 5 , RMSE: 0.48793625508917904
#
# Site Id: 2 , Meter: 0 , CV RMSE: 1.8695708048457664
#
# 5 fold CV for site_id: 2 for meter: 1
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [44]	training's rmse: 0.847921	valid_1's rmse: 1.15713
# Site Id: 2 , Meter: 1 , Fold: 1 , RMSE: 1.1533458033698225
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.801541	valid_1's rmse: 0.902656
# Early stopping, best iteration is:
# [135]	training's rmse: 0.768331	valid_1's rmse: 0.901276
# Site Id: 2 , Meter: 1 , Fold: 2 , RMSE: 0.9072750481227067
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [60]	training's rmse: 0.818517	valid_1's rmse: 1.03317
# Site Id: 2 , Meter: 1 , Fold: 3 , RMSE: 1.0348479139666746
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.783243	valid_1's rmse: 1.46012
# [200]	training's rmse: 0.710052	valid_1's rmse: 1.45609
# Early stopping, best iteration is:
# [202]	training's rmse: 0.709028	valid_1's rmse: 1.45578
# Site Id: 2 , Meter: 1 , Fold: 4 , RMSE: 1.449912745164719
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [70]	training's rmse: 0.855302	valid_1's rmse: 1.30725
# Site Id: 2 , Meter: 1 , Fold: 5 , RMSE: 1.22777309803395
#
# Site Id: 2 , Meter: 1 , CV RMSE: 2.3092541099784385
#
# 5 fold CV for site_id: 2 for meter: 2
# 5 fold CV for site_id: 2 for meter: 3
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.548327	valid_1's rmse: 0.885618
# Early stopping, best iteration is:
# [107]	training's rmse: 0.542304	valid_1's rmse: 0.884732
# Site Id: 2 , Meter: 3 , Fold: 1 , RMSE: 0.9246840884059377
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.605004	valid_1's rmse: 0.80957
# [200]	training's rmse: 0.549381	valid_1's rmse: 0.797302
# Early stopping, best iteration is:
# [267]	training's rmse: 0.523309	valid_1's rmse: 0.793026
# Site Id: 2 , Meter: 3 , Fold: 2 , RMSE: 0.811821660054076
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.614596	valid_1's rmse: 1.04733
# Early stopping, best iteration is:
# [145]	training's rmse: 0.587115	valid_1's rmse: 1.04464
# Site Id: 2 , Meter: 3 , Fold: 3 , RMSE: 1.0477412885038093
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.659733	valid_1's rmse: 1.01354
# Early stopping, best iteration is:
# [170]	training's rmse: 0.618056	valid_1's rmse: 1.00929
# Site Id: 2 , Meter: 3 , Fold: 4 , RMSE: 0.9904234088716413
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [72]	training's rmse: 0.71523	valid_1's rmse: 1.03318
# Site Id: 2 , Meter: 3 , Fold: 5 , RMSE: 1.005893046935688
#
# Site Id: 2 , Meter: 3 , CV RMSE: 1.503714512249143
#
# 5 fold CV for site_id: 3 for meter: 0
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.310874	valid_1's rmse: 0.482278
# Early stopping, best iteration is:
# [88]	training's rmse: 0.317149	valid_1's rmse: 0.480392
# Site Id: 3 , Meter: 0 , Fold: 1 , RMSE: 0.4725906715439927
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.324048	valid_1's rmse: 0.414936
# Early stopping, best iteration is:
# [84]	training's rmse: 0.332815	valid_1's rmse: 0.412555
# Site Id: 3 , Meter: 0 , Fold: 2 , RMSE: 0.40978848921178984
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.330011	valid_1's rmse: 0.347065
# Early stopping, best iteration is:
# [106]	training's rmse: 0.327786	valid_1's rmse: 0.346496
# Site Id: 3 , Meter: 0 , Fold: 3 , RMSE: 0.3472175247084657
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.323835	valid_1's rmse: 0.425711
# Early stopping, best iteration is:
# [106]	training's rmse: 0.321827	valid_1's rmse: 0.42525
# Site Id: 3 , Meter: 0 , Fold: 4 , RMSE: 0.4249303440874389
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.327483	valid_1's rmse: 0.388729
# Early stopping, best iteration is:
# [108]	training's rmse: 0.324528	valid_1's rmse: 0.38768
# Site Id: 3 , Meter: 0 , Fold: 5 , RMSE: 0.388547112556874
#
# Site Id: 3 , Meter: 0 , CV RMSE: 1.69616376113402
#
# 5 fold CV for site_id: 3 for meter: 1
# 5 fold CV for site_id: 3 for meter: 2
# 5 fold CV for site_id: 3 for meter: 3
# 5 fold CV for site_id: 4 for meter: 0
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.192157	valid_1's rmse: 0.292782
# Early stopping, best iteration is:
# [172]	training's rmse: 0.173458	valid_1's rmse: 0.286501
# Site Id: 4 , Meter: 0 , Fold: 1 , RMSE: 0.288326637266178
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.199055	valid_1's rmse: 0.296656
# Early stopping, best iteration is:
# [95]	training's rmse: 0.201133	valid_1's rmse: 0.296274
# Site Id: 4 , Meter: 0 , Fold: 2 , RMSE: 0.299773528980373
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.211436	valid_1's rmse: 0.238457
# [200]	training's rmse: 0.188692	valid_1's rmse: 0.221781
# [300]	training's rmse: 0.178163	valid_1's rmse: 0.220147
# Early stopping, best iteration is:
# [305]	training's rmse: 0.177677	valid_1's rmse: 0.220029
# Site Id: 4 , Meter: 0 , Fold: 3 , RMSE: 0.23172568559047413
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.195758	valid_1's rmse: 0.285441
# [200]	training's rmse: 0.174096	valid_1's rmse: 0.278851
# Early stopping, best iteration is:
# [245]	training's rmse: 0.169857	valid_1's rmse: 0.277407
# Site Id: 4 , Meter: 0 , Fold: 4 , RMSE: 0.2767801739357862
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.191565	valid_1's rmse: 0.209968
# Early stopping, best iteration is:
# [155]	training's rmse: 0.176585	valid_1's rmse: 0.20715
# Site Id: 4 , Meter: 0 , Fold: 5 , RMSE: 0.20577181232670494
#
# Site Id: 4 , Meter: 0 , CV RMSE: 1.636719966975456
#
# 5 fold CV for site_id: 4 for meter: 1
# 5 fold CV for site_id: 4 for meter: 2
# 5 fold CV for site_id: 4 for meter: 3
# 5 fold CV for site_id: 5 for meter: 0
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.376261	valid_1's rmse: 0.800767
# [200]	training's rmse: 0.344111	valid_1's rmse: 0.797731
# [300]	training's rmse: 0.324538	valid_1's rmse: 0.796311
# Early stopping, best iteration is:
# [290]	training's rmse: 0.326117	valid_1's rmse: 0.796022
# Site Id: 5 , Meter: 0 , Fold: 1 , RMSE: 0.8023041792851273
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.49388	valid_1's rmse: 0.785175
# Early stopping, best iteration is:
# [144]	training's rmse: 0.468688	valid_1's rmse: 0.781615
# Site Id: 5 , Meter: 0 , Fold: 2 , RMSE: 0.7788702929284306
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.540874	valid_1's rmse: 0.510459
# [200]	training's rmse: 0.49403	valid_1's rmse: 0.488264
# [300]	training's rmse: 0.467579	valid_1's rmse: 0.475943
# [400]	training's rmse: 0.44807	valid_1's rmse: 0.472454
# [500]	training's rmse: 0.432124	valid_1's rmse: 0.466097
# [600]	training's rmse: 0.41887	valid_1's rmse: 0.462959
# [700]	training's rmse: 0.408257	valid_1's rmse: 0.459979
# Early stopping, best iteration is:
# [768]	training's rmse: 0.402577	valid_1's rmse: 0.45702
# Site Id: 5 , Meter: 0 , Fold: 3 , RMSE: 0.4727047794338226
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.523308	valid_1's rmse: 0.635405
# [200]	training's rmse: 0.477716	valid_1's rmse: 0.61301
# [300]	training's rmse: 0.452661	valid_1's rmse: 0.602172
# [400]	training's rmse: 0.434043	valid_1's rmse: 0.597165
# [500]	training's rmse: 0.417296	valid_1's rmse: 0.593493
# [600]	training's rmse: 0.404075	valid_1's rmse: 0.589782
# [700]	training's rmse: 0.391662	valid_1's rmse: 0.585912
# [800]	training's rmse: 0.382131	valid_1's rmse: 0.583292
# [900]	training's rmse: 0.37382	valid_1's rmse: 0.580593
# [1000]	training's rmse: 0.365923	valid_1's rmse: 0.57837
# [1100]	training's rmse: 0.358962	valid_1's rmse: 0.57675
# [1200]	training's rmse: 0.353301	valid_1's rmse: 0.575291
# [1300]	training's rmse: 0.348195	valid_1's rmse: 0.574124
# [1400]	training's rmse: 0.342758	valid_1's rmse: 0.572935
# [1500]	training's rmse: 0.3376	valid_1's rmse: 0.57166
# Did not meet early stopping. Best iteration is:
# [1500]	training's rmse: 0.3376	valid_1's rmse: 0.57166
# Site Id: 5 , Meter: 0 , Fold: 4 , RMSE: 0.5702861079138442
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.530186	valid_1's rmse: 0.780276
# [200]	training's rmse: 0.482304	valid_1's rmse: 0.763223
# [300]	training's rmse: 0.454779	valid_1's rmse: 0.756255
# Early stopping, best iteration is:
# [345]	training's rmse: 0.444619	valid_1's rmse: 0.755156
# Site Id: 5 , Meter: 0 , Fold: 5 , RMSE: 0.7483842824938023
#
# Site Id: 5 , Meter: 0 , CV RMSE: 1.2519625376947583
#
# 5 fold CV for site_id: 5 for meter: 1
# 5 fold CV for site_id: 5 for meter: 2
# 5 fold CV for site_id: 5 for meter: 3
# 5 fold CV for site_id: 6 for meter: 0
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [3]	training's rmse: 0.739374	valid_1's rmse: 0.731652
# Site Id: 6 , Meter: 0 , Fold: 1 , RMSE: 0.7316515668432781
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.162138	valid_1's rmse: 0.442838
# Early stopping, best iteration is:
# [170]	training's rmse: 0.147732	valid_1's rmse: 0.439747
# Site Id: 6 , Meter: 0 , Fold: 2 , RMSE: 0.4387275297575619
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.197498	valid_1's rmse: 0.208703
# Early stopping, best iteration is:
# [131]	training's rmse: 0.187379	valid_1's rmse: 0.200431
# Site Id: 6 , Meter: 0 , Fold: 3 , RMSE: 0.19917454854276964
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.186777	valid_1's rmse: 0.235237
# [200]	training's rmse: 0.165779	valid_1's rmse: 0.227859
# [300]	training's rmse: 0.153622	valid_1's rmse: 0.227096
# Early stopping, best iteration is:
# [298]	training's rmse: 0.153767	valid_1's rmse: 0.227065
# Site Id: 6 , Meter: 0 , Fold: 4 , RMSE: 0.23061204287954445
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.180015	valid_1's rmse: 0.250552
# [200]	training's rmse: 0.159062	valid_1's rmse: 0.245559
# [300]	training's rmse: 0.147547	valid_1's rmse: 0.244183
# Early stopping, best iteration is:
# [300]	training's rmse: 0.147547	valid_1's rmse: 0.244183
# Site Id: 6 , Meter: 0 , Fold: 5 , RMSE: 0.24494760913850994
#
# Site Id: 6 , Meter: 0 , CV RMSE: 1.6231954478209325
#
# 5 fold CV for site_id: 6 for meter: 1
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.64501	valid_1's rmse: 1.5282
# Early stopping, best iteration is:
# [176]	training's rmse: 0.568679	valid_1's rmse: 1.52005
# Site Id: 6 , Meter: 1 , Fold: 1 , RMSE: 1.460081748364739
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.821729	valid_1's rmse: 1.54916
# Early stopping, best iteration is:
# [125]	training's rmse: 0.787215	valid_1's rmse: 1.54687
# Site Id: 6 , Meter: 1 , Fold: 2 , RMSE: 1.5780840934316567
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.928185	valid_1's rmse: 1.12629
# Early stopping, best iteration is:
# [83]	training's rmse: 0.960489	valid_1's rmse: 1.11487
# Site Id: 6 , Meter: 1 , Fold: 3 , RMSE: 1.0586709287853002
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.925103	valid_1's rmse: 2.57092
# Early stopping, best iteration is:
# [140]	training's rmse: 0.883112	valid_1's rmse: 2.56701
# Site Id: 6 , Meter: 1 , Fold: 4 , RMSE: 2.604567582301338
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.1138	valid_1's rmse: 1.7
# [200]	training's rmse: 0.99143	valid_1's rmse: 1.65804
# Early stopping, best iteration is:
# [215]	training's rmse: 0.981085	valid_1's rmse: 1.6545
# Site Id: 6 , Meter: 1 , Fold: 5 , RMSE: 1.756842704179543
#
# Site Id: 6 , Meter: 1 , CV RMSE: 2.151216452478717
#
# 5 fold CV for site_id: 6 for meter: 2
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.795721	valid_1's rmse: 1.89189
# Early stopping, best iteration is:
# [137]	training's rmse: 0.73658	valid_1's rmse: 1.87748
# Site Id: 6 , Meter: 2 , Fold: 1 , RMSE: 1.8882217617042696
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [74]	training's rmse: 1.05855	valid_1's rmse: 1.33186
# Site Id: 6 , Meter: 2 , Fold: 2 , RMSE: 1.29651052112453
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.956398	valid_1's rmse: 1.51542
# Early stopping, best iteration is:
# [168]	training's rmse: 0.88341	valid_1's rmse: 1.50075
# Site Id: 6 , Meter: 2 , Fold: 3 , RMSE: 1.4586094336665028
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.03029	valid_1's rmse: 1.95866
# Early stopping, best iteration is:
# [91]	training's rmse: 1.04689	valid_1's rmse: 1.95078
# Site Id: 6 , Meter: 2 , Fold: 4 , RMSE: 1.9561157392223205
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.0862	valid_1's rmse: 2.13482
# Early stopping, best iteration is:
# [91]	training's rmse: 1.10336	valid_1's rmse: 2.12936
# Site Id: 6 , Meter: 2 , Fold: 5 , RMSE: 2.0627024053336522
#
# Site Id: 6 , Meter: 2 , CV RMSE: 2.8268052402210655
#
# 5 fold CV for site_id: 6 for meter: 3
# 5 fold CV for site_id: 7 for meter: 0
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [1]	training's rmse: 0.293542	valid_1's rmse: 1.41352
# Site Id: 7 , Meter: 0 , Fold: 1 , RMSE: 1.413524139344203
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [73]	training's rmse: 0.173513	valid_1's rmse: 0.377289
# Site Id: 7 , Meter: 0 , Fold: 2 , RMSE: 0.37600367262581813
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [10]	training's rmse: 0.54278	valid_1's rmse: 3.73179
# Site Id: 7 , Meter: 0 , Fold: 3 , RMSE: 3.7317922770805283
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.532446	valid_1's rmse: 0.755989
# Early stopping, best iteration is:
# [93]	training's rmse: 0.547924	valid_1's rmse: 0.753645
# Site Id: 7 , Meter: 0 , Fold: 4 , RMSE: 0.755038779124935
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.520332	valid_1's rmse: 3.59689
# [200]	training's rmse: 0.399844	valid_1's rmse: 3.56487
# [300]	training's rmse: 0.347155	valid_1's rmse: 3.54225
# [400]	training's rmse: 0.310931	valid_1's rmse: 3.53568
# Early stopping, best iteration is:
# [395]	training's rmse: 0.311886	valid_1's rmse: 3.53289
# Site Id: 7 , Meter: 0 , Fold: 5 , RMSE: 3.5168662350054003
#
# Site Id: 7 , Meter: 0 , CV RMSE: 3.5271923093687905
#
# 5 fold CV for site_id: 7 for meter: 1
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.227828	valid_1's rmse: 2.32714
# [200]	training's rmse: 0.183382	valid_1's rmse: 2.31716
# Early stopping, best iteration is:
# [207]	training's rmse: 0.181418	valid_1's rmse: 2.31692
# Site Id: 7 , Meter: 1 , Fold: 1 , RMSE: 2.315665388947032
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [79]	training's rmse: 0.471095	valid_1's rmse: 1.93148
# Site Id: 7 , Meter: 1 , Fold: 2 , RMSE: 1.9314770573881461
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.667156	valid_1's rmse: 1.6311
# Early stopping, best iteration is:
# [134]	training's rmse: 0.622809	valid_1's rmse: 1.6187
# Site Id: 7 , Meter: 1 , Fold: 3 , RMSE: 1.5388865228830515
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.817608	valid_1's rmse: 1.3323
# [200]	training's rmse: 0.705051	valid_1's rmse: 1.3097
# Early stopping, best iteration is:
# [193]	training's rmse: 0.709528	valid_1's rmse: 1.30934
# Site Id: 7 , Meter: 1 , Fold: 4 , RMSE: 1.3046224079151176
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.851739	valid_1's rmse: 1.2681
# Early stopping, best iteration is:
# [129]	training's rmse: 0.80951	valid_1's rmse: 1.25813
# Site Id: 7 , Meter: 1 , Fold: 5 , RMSE: 1.2707726819356704
#
# Site Id: 7 , Meter: 1 , CV RMSE: 2.7164348780484846
#
# 5 fold CV for site_id: 7 for meter: 2
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [66]	training's rmse: 0.677238	valid_1's rmse: 2.16576
# Site Id: 7 , Meter: 2 , Fold: 1 , RMSE: 2.1803252441164758
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.75015	valid_1's rmse: 1.76742
# Early stopping, best iteration is:
# [153]	training's rmse: 0.685868	valid_1's rmse: 1.75379
# Site Id: 7 , Meter: 2 , Fold: 2 , RMSE: 1.7510985190481374
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.920751	valid_1's rmse: 1.90326
# [200]	training's rmse: 0.817424	valid_1's rmse: 1.87369
# Early stopping, best iteration is:
# [190]	training's rmse: 0.824845	valid_1's rmse: 1.8733
# Site Id: 7 , Meter: 2 , Fold: 3 , RMSE: 1.8755589272485824
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.07377	valid_1's rmse: 1.19266
# Early stopping, best iteration is:
# [156]	training's rmse: 1.00495	valid_1's rmse: 1.18248
# Site Id: 7 , Meter: 2 , Fold: 4 , RMSE: 1.174003147475735
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.03936	valid_1's rmse: 1.0201
# [200]	training's rmse: 0.932641	valid_1's rmse: 0.980887
# [300]	training's rmse: 0.867846	valid_1's rmse: 0.969369
# [400]	training's rmse: 0.82196	valid_1's rmse: 0.963653
# Early stopping, best iteration is:
# [385]	training's rmse: 0.829892	valid_1's rmse: 0.963069
# Site Id: 7 , Meter: 2 , Fold: 5 , RMSE: 1.0219807192715125
#
# Site Id: 7 , Meter: 2 , CV RMSE: 2.5161641781278368
#
# 5 fold CV for site_id: 7 for meter: 3
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.926485	valid_1's rmse: 1.74055
# Early stopping, best iteration is:
# [100]	training's rmse: 0.926485	valid_1's rmse: 1.74055
# Site Id: 7 , Meter: 3 , Fold: 1 , RMSE: 1.740546648921632
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [60]	training's rmse: 1.20506	valid_1's rmse: 3.06103
# Site Id: 7 , Meter: 3 , Fold: 2 , RMSE: 3.0610339118152563
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.24135	valid_1's rmse: 1.78291
# Early stopping, best iteration is:
# [115]	training's rmse: 1.2117	valid_1's rmse: 1.77794
# Site Id: 7 , Meter: 3 , Fold: 3 , RMSE: 1.77794181091015
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [71]	training's rmse: 1.31255	valid_1's rmse: 1.90221
# Site Id: 7 , Meter: 3 , Fold: 4 , RMSE: 1.9022118856946955
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.30788	valid_1's rmse: 1.76869
# Early stopping, best iteration is:
# [125]	training's rmse: 1.26661	valid_1's rmse: 1.75794
# Site Id: 7 , Meter: 3 , Fold: 5 , RMSE: 1.7579393256312452
#
# Site Id: 7 , Meter: 3 , CV RMSE: 2.925283660519988
#
# 5 fold CV for site_id: 8 for meter: 0
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.413052	valid_1's rmse: 0.757658
# Early stopping, best iteration is:
# [119]	training's rmse: 0.402272	valid_1's rmse: 0.755345
# Site Id: 8 , Meter: 0 , Fold: 1 , RMSE: 0.7552432824823605
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [30]	training's rmse: 0.540236	valid_1's rmse: 0.608542
# Site Id: 8 , Meter: 0 , Fold: 2 , RMSE: 0.6085415897474469
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.412388	valid_1's rmse: 0.379493
# Early stopping, best iteration is:
# [134]	training's rmse: 0.396474	valid_1's rmse: 0.378818
# Site Id: 8 , Meter: 0 , Fold: 3 , RMSE: 0.3784452089444109
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.400354	valid_1's rmse: 0.776944
# Early stopping, best iteration is:
# [124]	training's rmse: 0.390912	valid_1's rmse: 0.776182
# Site Id: 8 , Meter: 0 , Fold: 4 , RMSE: 0.7789839219092524
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.433106	valid_1's rmse: 0.680387
# Early stopping, best iteration is:
# [135]	training's rmse: 0.419818	valid_1's rmse: 0.673283
# Site Id: 8 , Meter: 0 , Fold: 5 , RMSE: 0.7177688069430853
#
# Site Id: 8 , Meter: 0 , CV RMSE: 1.210704162000504
#
# 5 fold CV for site_id: 8 for meter: 1
# 5 fold CV for site_id: 8 for meter: 2
# 5 fold CV for site_id: 8 for meter: 3
# 5 fold CV for site_id: 9 for meter: 0
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.433934	valid_1's rmse: 0.670669
# [200]	training's rmse: 0.294664	valid_1's rmse: 0.618998
# [300]	training's rmse: 0.247847	valid_1's rmse: 0.611178
# [400]	training's rmse: 0.225254	valid_1's rmse: 0.607377
# [500]	training's rmse: 0.205853	valid_1's rmse: 0.605895
# [600]	training's rmse: 0.192668	valid_1's rmse: 0.605054
# [700]	training's rmse: 0.182992	valid_1's rmse: 0.604268
# Early stopping, best iteration is:
# [723]	training's rmse: 0.181273	valid_1's rmse: 0.604145
# Site Id: 9 , Meter: 0 , Fold: 1 , RMSE: 0.6066189417480716
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.450611	valid_1's rmse: 0.611951
# [200]	training's rmse: 0.321512	valid_1's rmse: 0.552466
# [300]	training's rmse: 0.275752	valid_1's rmse: 0.5419
# Early stopping, best iteration is:
# [333]	training's rmse: 0.265648	valid_1's rmse: 0.538934
# Site Id: 9 , Meter: 0 , Fold: 2 , RMSE: 0.526724326679373
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.455089	valid_1's rmse: 0.902187
# [200]	training's rmse: 0.332279	valid_1's rmse: 0.868547
# Early stopping, best iteration is:
# [245]	training's rmse: 0.309045	valid_1's rmse: 0.864888
# Site Id: 9 , Meter: 0 , Fold: 3 , RMSE: 0.8645876387691939
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.50061	valid_1's rmse: 0.459997
# Early stopping, best iteration is:
# [152]	training's rmse: 0.416239	valid_1's rmse: 0.437536
# Site Id: 9 , Meter: 0 , Fold: 4 , RMSE: 0.3628893597243374
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.494935	valid_1's rmse: 0.749096
# [200]	training's rmse: 0.370267	valid_1's rmse: 0.712165
# [300]	training's rmse: 0.322556	valid_1's rmse: 0.705389
# [400]	training's rmse: 0.294286	valid_1's rmse: 0.702123
# [500]	training's rmse: 0.273407	valid_1's rmse: 0.700028
# Early stopping, best iteration is:
# [547]	training's rmse: 0.265975	valid_1's rmse: 0.699305
# Site Id: 9 , Meter: 0 , Fold: 5 , RMSE: 0.6953978685904817
#
# Site Id: 9 , Meter: 0 , CV RMSE: 1.9523384881062034
#
# 5 fold CV for site_id: 9 for meter: 1
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.605402	valid_1's rmse: 0.83023
# [200]	training's rmse: 0.462661	valid_1's rmse: 0.788955
# [300]	training's rmse: 0.399688	valid_1's rmse: 0.777853
# [400]	training's rmse: 0.359071	valid_1's rmse: 0.771925
# [500]	training's rmse: 0.332552	valid_1's rmse: 0.768785
# [600]	training's rmse: 0.308183	valid_1's rmse: 0.765855
# [700]	training's rmse: 0.292259	valid_1's rmse: 0.763884
# [800]	training's rmse: 0.277673	valid_1's rmse: 0.761918
# [900]	training's rmse: 0.265553	valid_1's rmse: 0.760616
# [1000]	training's rmse: 0.253841	valid_1's rmse: 0.759249
# Early stopping, best iteration is:
# [1045]	training's rmse: 0.249114	valid_1's rmse: 0.758415
# Site Id: 9 , Meter: 1 , Fold: 1 , RMSE: 0.7215506843073317
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.61494	valid_1's rmse: 0.984186
# [200]	training's rmse: 0.492337	valid_1's rmse: 0.919108
# [300]	training's rmse: 0.446894	valid_1's rmse: 0.906393
# [400]	training's rmse: 0.403045	valid_1's rmse: 0.899151
# [500]	training's rmse: 0.37957	valid_1's rmse: 0.895712
# [600]	training's rmse: 0.360005	valid_1's rmse: 0.892357
# Early stopping, best iteration is:
# [620]	training's rmse: 0.355057	valid_1's rmse: 0.891971
# Site Id: 9 , Meter: 1 , Fold: 2 , RMSE: 0.8742107113012416
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.654675	valid_1's rmse: 1.31324
# [200]	training's rmse: 0.53245	valid_1's rmse: 1.28488
# Early stopping, best iteration is:
# [194]	training's rmse: 0.536318	valid_1's rmse: 1.28326
# Site Id: 9 , Meter: 1 , Fold: 3 , RMSE: 1.268623687763053
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.729371	valid_1's rmse: 0.949581
# [200]	training's rmse: 0.582356	valid_1's rmse: 0.909907
# [300]	training's rmse: 0.516174	valid_1's rmse: 0.900862
# [400]	training's rmse: 0.47681	valid_1's rmse: 0.895869
# Early stopping, best iteration is:
# [407]	training's rmse: 0.474723	valid_1's rmse: 0.895034
# Site Id: 9 , Meter: 1 , Fold: 4 , RMSE: 0.8554471258944368
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.750279	valid_1's rmse: 1.06327
# [200]	training's rmse: 0.618406	valid_1's rmse: 1.03407
# [300]	training's rmse: 0.547532	valid_1's rmse: 1.01975
# [400]	training's rmse: 0.50462	valid_1's rmse: 1.01338
# Early stopping, best iteration is:
# [403]	training's rmse: 0.503762	valid_1's rmse: 1.0133
# Site Id: 9 , Meter: 1 , Fold: 5 , RMSE: 1.0008036117362469
#
# Site Id: 9 , Meter: 1 , CV RMSE: 2.41845961488901
#
# 5 fold CV for site_id: 9 for meter: 2
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.957461	valid_1's rmse: 1.23712
# [200]	training's rmse: 0.884267	valid_1's rmse: 1.21296
# Early stopping, best iteration is:
# [250]	training's rmse: 0.861887	valid_1's rmse: 1.21106
# Site Id: 9 , Meter: 2 , Fold: 1 , RMSE: 1.2015778230773384
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.01035	valid_1's rmse: 1.36232
# [200]	training's rmse: 0.937633	valid_1's rmse: 1.33223
# Early stopping, best iteration is:
# [218]	training's rmse: 0.928929	valid_1's rmse: 1.3306
# Site Id: 9 , Meter: 2 , Fold: 2 , RMSE: 1.3103625525282467
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.06996	valid_1's rmse: 1.37005
# [200]	training's rmse: 0.993173	valid_1's rmse: 1.34148
# [300]	training's rmse: 0.956719	valid_1's rmse: 1.33617
# Early stopping, best iteration is:
# [351]	training's rmse: 0.944997	valid_1's rmse: 1.33455
# Site Id: 9 , Meter: 2 , Fold: 3 , RMSE: 1.3270670990728157
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.07612	valid_1's rmse: 1.25261
# Early stopping, best iteration is:
# [95]	training's rmse: 1.08214	valid_1's rmse: 1.24357
# Site Id: 9 , Meter: 2 , Fold: 4 , RMSE: 1.2153083223181467
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.07585	valid_1's rmse: 1.20026
# [200]	training's rmse: 0.993629	valid_1's rmse: 1.16075
# [300]	training's rmse: 0.957443	valid_1's rmse: 1.14973
# [400]	training's rmse: 0.934884	valid_1's rmse: 1.14485
# [500]	training's rmse: 0.918352	valid_1's rmse: 1.14108
# Early stopping, best iteration is:
# [504]	training's rmse: 0.917805	valid_1's rmse: 1.14071
# Site Id: 9 , Meter: 2 , Fold: 5 , RMSE: 1.1319495594957583
#
# Site Id: 9 , Meter: 2 , CV RMSE: 2.0717998732856957
#
# 5 fold CV for site_id: 9 for meter: 3
# 5 fold CV for site_id: 10 for meter: 0
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.299708	valid_1's rmse: 0.582986
# Early stopping, best iteration is:
# [126]	training's rmse: 0.287979	valid_1's rmse: 0.580829
# Site Id: 10 , Meter: 0 , Fold: 1 , RMSE: 0.5818917555755676
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.298723	valid_1's rmse: 0.706875
# Early stopping, best iteration is:
# [161]	training's rmse: 0.277744	valid_1's rmse: 0.693902
# Site Id: 10 , Meter: 0 , Fold: 2 , RMSE: 0.6970382895310451
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [22]	training's rmse: 0.530424	valid_1's rmse: 0.872013
# Site Id: 10 , Meter: 0 , Fold: 3 , RMSE: 0.8720134185512897
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.390466	valid_1's rmse: 0.196809
# Early stopping, best iteration is:
# [141]	training's rmse: 0.371259	valid_1's rmse: 0.195366
# Site Id: 10 , Meter: 0 , Fold: 4 , RMSE: 0.19843268315183094
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [39]	training's rmse: 0.432989	valid_1's rmse: 0.215578
# Site Id: 10 , Meter: 0 , Fold: 5 , RMSE: 0.2157952459855236
#
# Site Id: 10 , Meter: 0 , CV RMSE: 1.7969346645491988
#
# 5 fold CV for site_id: 10 for meter: 1
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.932579	valid_1's rmse: 1.40997
# Early stopping, best iteration is:
# [101]	training's rmse: 0.931141	valid_1's rmse: 1.40988
# Site Id: 10 , Meter: 1 , Fold: 1 , RMSE: 1.4098786156283063
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.01752	valid_1's rmse: 1.79279
# Early stopping, best iteration is:
# [103]	training's rmse: 1.01333	valid_1's rmse: 1.7925
# Site Id: 10 , Meter: 1 , Fold: 2 , RMSE: 1.7924997723743394
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.08148	valid_1's rmse: 1.6526
# [200]	training's rmse: 0.996083	valid_1's rmse: 1.6257
# Early stopping, best iteration is:
# [205]	training's rmse: 0.993132	valid_1's rmse: 1.62461
# Site Id: 10 , Meter: 1 , Fold: 3 , RMSE: 1.6282454738771301
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.11842	valid_1's rmse: 1.23907
# [200]	training's rmse: 1.02733	valid_1's rmse: 1.2267
# Early stopping, best iteration is:
# [211]	training's rmse: 1.02106	valid_1's rmse: 1.22623
# Site Id: 10 , Meter: 1 , Fold: 4 , RMSE: 1.2262313372310694
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.09669	valid_1's rmse: 0.0555054
# Early stopping, best iteration is:
# [94]	training's rmse: 1.10383	valid_1's rmse: 0.0540113
# Site Id: 10 , Meter: 1 , Fold: 5 , RMSE: 0.08742043470067563
#
# Site Id: 10 , Meter: 1 , CV RMSE: 1.722922520718069
#
# 5 fold CV for site_id: 10 for meter: 2
# 5 fold CV for site_id: 10 for meter: 3
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [17]	training's rmse: 1.72508	valid_1's rmse: 2.66599
# Site Id: 10 , Meter: 3 , Fold: 1 , RMSE: 2.6659899736342996
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.883818	valid_1's rmse: 1.5191
# Early stopping, best iteration is:
# [173]	training's rmse: 0.827168	valid_1's rmse: 1.51689
# Site Id: 10 , Meter: 3 , Fold: 2 , RMSE: 1.4885285139367281
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.881675	valid_1's rmse: 1.57794
# Early stopping, best iteration is:
# [140]	training's rmse: 0.847569	valid_1's rmse: 1.57238
# Site Id: 10 , Meter: 3 , Fold: 3 , RMSE: 1.5882102714991564
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [44]	training's rmse: 1.11536	valid_1's rmse: 4.00621
# Site Id: 10 , Meter: 3 , Fold: 4 , RMSE: 4.027594366844739
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.20138	valid_1's rmse: 3.25418
# Early stopping, best iteration is:
# [161]	training's rmse: 1.12661	valid_1's rmse: 3.21853
# Site Id: 10 , Meter: 3 , Fold: 5 , RMSE: 3.213799787601992
#
# Site Id: 10 , Meter: 3 , CV RMSE: 3.1708593812326082
#
# 5 fold CV for site_id: 11 for meter: 0
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.0495501	valid_1's rmse: 1.08449
# Early stopping, best iteration is:
# [115]	training's rmse: 0.047344	valid_1's rmse: 1.08374
# Site Id: 11 , Meter: 0 , Fold: 1 , RMSE: 1.0837405716261392
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [6]	training's rmse: 0.534056	valid_1's rmse: 0.709199
# Site Id: 11 , Meter: 0 , Fold: 2 , RMSE: 0.7091994755688229
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.0751238	valid_1's rmse: 0.225207
# [200]	training's rmse: 0.0613853	valid_1's rmse: 0.221578
# Early stopping, best iteration is:
# [202]	training's rmse: 0.0612833	valid_1's rmse: 0.221561
# Site Id: 11 , Meter: 0 , Fold: 3 , RMSE: 0.2180272447764505
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.0819116	valid_1's rmse: 0.300709
# [200]	training's rmse: 0.0679546	valid_1's rmse: 0.290133
# Early stopping, best iteration is:
# [235]	training's rmse: 0.0652472	valid_1's rmse: 0.289716
# Site Id: 11 , Meter: 0 , Fold: 4 , RMSE: 0.2885309425857433
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.0920694	valid_1's rmse: 0.292418
# [200]	training's rmse: 0.0767361	valid_1's rmse: 0.283913
# Early stopping, best iteration is:
# [231]	training's rmse: 0.0742265	valid_1's rmse: 0.283533
# Site Id: 11 , Meter: 0 , Fold: 5 , RMSE: 0.2835333401378921
#
# Site Id: 11 , Meter: 0 , CV RMSE: 2.385954807219253
#
# 5 fold CV for site_id: 11 for meter: 1
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.359364	valid_1's rmse: 0.681117
# [200]	training's rmse: 0.256048	valid_1's rmse: 0.647867
# [300]	training's rmse: 0.203642	valid_1's rmse: 0.638401
# Early stopping, best iteration is:
# [315]	training's rmse: 0.197058	valid_1's rmse: 0.637908
# Site Id: 11 , Meter: 1 , Fold: 1 , RMSE: 0.6389564747880508
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.35155	valid_1's rmse: 0.64618
# [200]	training's rmse: 0.277202	valid_1's rmse: 0.561272
# [300]	training's rmse: 0.238393	valid_1's rmse: 0.525465
# [400]	training's rmse: 0.215662	valid_1's rmse: 0.504094
# [500]	training's rmse: 0.198374	valid_1's rmse: 0.489722
# [600]	training's rmse: 0.185518	valid_1's rmse: 0.478101
# [700]	training's rmse: 0.174799	valid_1's rmse: 0.470773
# [800]	training's rmse: 0.167462	valid_1's rmse: 0.462489
# Early stopping, best iteration is:
# [814]	training's rmse: 0.16592	valid_1's rmse: 0.462479
# Site Id: 11 , Meter: 1 , Fold: 2 , RMSE: 0.4624789203321367
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [33]	training's rmse: 0.714146	valid_1's rmse: 1.47487
# Site Id: 11 , Meter: 1 , Fold: 3 , RMSE: 1.4748749629736597
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.488317	valid_1's rmse: 1.05228
# Early stopping, best iteration is:
# [101]	training's rmse: 0.48656	valid_1's rmse: 1.05005
# Site Id: 11 , Meter: 1 , Fold: 4 , RMSE: 1.0349950249901307
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.554751	valid_1's rmse: 0.956391
# Early stopping, best iteration is:
# [176]	training's rmse: 0.483043	valid_1's rmse: 0.931474
# Site Id: 11 , Meter: 1 , Fold: 5 , RMSE: 0.9314742842827188
#
# Site Id: 11 , Meter: 1 , CV RMSE: 1.4233585308489574
#
# 5 fold CV for site_id: 11 for meter: 2
# 5 fold CV for site_id: 11 for meter: 3
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [17]	training's rmse: 1.08883	valid_1's rmse: 1.43738
# Site Id: 11 , Meter: 3 , Fold: 1 , RMSE: 1.4373844796813915
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.450808	valid_1's rmse: 1.38054
# Early stopping, best iteration is:
# [160]	training's rmse: 0.402353	valid_1's rmse: 1.3663
# Site Id: 11 , Meter: 3 , Fold: 2 , RMSE: 1.3662950368635756
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.491451	valid_1's rmse: 0.771583
# [200]	training's rmse: 0.427697	valid_1's rmse: 0.755437
# Early stopping, best iteration is:
# [205]	training's rmse: 0.424756	valid_1's rmse: 0.755147
# Site Id: 11 , Meter: 3 , Fold: 3 , RMSE: 0.7524274677863864
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.521103	valid_1's rmse: 0.775369
# [200]	training's rmse: 0.460354	valid_1's rmse: 0.76351
# Early stopping, best iteration is:
# [181]	training's rmse: 0.468126	valid_1's rmse: 0.763191
# Site Id: 11 , Meter: 3 , Fold: 4 , RMSE: 0.7571073040742531
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.5397	valid_1's rmse: 1.13577
# Early stopping, best iteration is:
# [154]	training's rmse: 0.502368	valid_1's rmse: 1.1155
# Site Id: 11 , Meter: 3 , Fold: 5 , RMSE: 1.1155035851399155
#
# Site Id: 11 , Meter: 3 , CV RMSE: 1.916288430673257
#
# 5 fold CV for site_id: 12 for meter: 0
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [75]	training's rmse: 0.442255	valid_1's rmse: 0.575952
# Site Id: 12 , Meter: 0 , Fold: 1 , RMSE: 0.5759519738771745
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.352962	valid_1's rmse: 0.303511
# [200]	training's rmse: 0.295832	valid_1's rmse: 0.272206
# [300]	training's rmse: 0.261532	valid_1's rmse: 0.259198
# [400]	training's rmse: 0.23962	valid_1's rmse: 0.254349
# [500]	training's rmse: 0.224071	valid_1's rmse: 0.24992
# [600]	training's rmse: 0.209685	valid_1's rmse: 0.24672
# [700]	training's rmse: 0.19915	valid_1's rmse: 0.244023
# Early stopping, best iteration is:
# [758]	training's rmse: 0.19331	valid_1's rmse: 0.242943
# Site Id: 12 , Meter: 0 , Fold: 2 , RMSE: 0.24635644582417618
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.331775	valid_1's rmse: 0.384912
# [200]	training's rmse: 0.272075	valid_1's rmse: 0.352324
# [300]	training's rmse: 0.241833	valid_1's rmse: 0.342715
# [400]	training's rmse: 0.220837	valid_1's rmse: 0.338999
# [500]	training's rmse: 0.207899	valid_1's rmse: 0.336024
# [600]	training's rmse: 0.196875	valid_1's rmse: 0.333965
# Early stopping, best iteration is:
# [670]	training's rmse: 0.189467	valid_1's rmse: 0.333209
# Site Id: 12 , Meter: 0 , Fold: 3 , RMSE: 0.33408833422770723
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.337166	valid_1's rmse: 0.371541
# [200]	training's rmse: 0.279391	valid_1's rmse: 0.364308
# [300]	training's rmse: 0.253964	valid_1's rmse: 0.363823
# Early stopping, best iteration is:
# [291]	training's rmse: 0.25604	valid_1's rmse: 0.363646
# Site Id: 12 , Meter: 0 , Fold: 4 , RMSE: 0.3633315767604423
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.345259	valid_1's rmse: 0.531212
# [200]	training's rmse: 0.294096	valid_1's rmse: 0.514269
# [300]	training's rmse: 0.27059	valid_1's rmse: 0.509937
# Early stopping, best iteration is:
# [344]	training's rmse: 0.263432	valid_1's rmse: 0.509217
# Site Id: 12 , Meter: 0 , Fold: 5 , RMSE: 0.5089433809111773
#
# Site Id: 12 , Meter: 0 , CV RMSE: 1.5096975045485237
#
# 5 fold CV for site_id: 12 for meter: 1
# 5 fold CV for site_id: 12 for meter: 2
# 5 fold CV for site_id: 12 for meter: 3
# 5 fold CV for site_id: 13 for meter: 0
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.24182	valid_1's rmse: 0.446907
# Early stopping, best iteration is:
# [108]	training's rmse: 0.237062	valid_1's rmse: 0.44643
# Site Id: 13 , Meter: 0 , Fold: 1 , RMSE: 0.4424596848943256
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.261706	valid_1's rmse: 0.323835
# [200]	training's rmse: 0.213933	valid_1's rmse: 0.318175
# Early stopping, best iteration is:
# [271]	training's rmse: 0.200283	valid_1's rmse: 0.317264
# Site Id: 13 , Meter: 0 , Fold: 2 , RMSE: 0.32388109325312175
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.254803	valid_1's rmse: 0.770492
# [200]	training's rmse: 0.211768	valid_1's rmse: 0.762884
# [300]	training's rmse: 0.19121	valid_1's rmse: 0.760662
# Early stopping, best iteration is:
# [292]	training's rmse: 0.191996	valid_1's rmse: 0.760452
# Site Id: 13 , Meter: 0 , Fold: 3 , RMSE: 0.7677166135851738
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.325577	valid_1's rmse: 0.473793
# Early stopping, best iteration is:
# [113]	training's rmse: 0.315952	valid_1's rmse: 0.473154
# Site Id: 13 , Meter: 0 , Fold: 4 , RMSE: 0.4726479473188888
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.337495	valid_1's rmse: 0.428203
# Early stopping, best iteration is:
# [98]	training's rmse: 0.339752	valid_1's rmse: 0.427927
# Site Id: 13 , Meter: 0 , Fold: 5 , RMSE: 0.42610720435984756
#
# Site Id: 13 , Meter: 0 , CV RMSE: 2.0163717238329673
#
# 5 fold CV for site_id: 13 for meter: 1
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.749247	valid_1's rmse: 1.24677
# [200]	training's rmse: 0.670013	valid_1's rmse: 1.23855
# Early stopping, best iteration is:
# [238]	training's rmse: 0.651859	valid_1's rmse: 1.2373
# Site Id: 13 , Meter: 1 , Fold: 1 , RMSE: 1.1153556678093721
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.76871	valid_1's rmse: 1.71826
# Early stopping, best iteration is:
# [91]	training's rmse: 0.780746	valid_1's rmse: 1.7166
# Site Id: 13 , Meter: 1 , Fold: 2 , RMSE: 1.7470214086068745
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.760704	valid_1's rmse: 1.52853
# Early stopping, best iteration is:
# [98]	training's rmse: 0.762667	valid_1's rmse: 1.52843
# Site Id: 13 , Meter: 1 , Fold: 3 , RMSE: 1.529841913470926
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.784301	valid_1's rmse: 1.30393
# [200]	training's rmse: 0.717296	valid_1's rmse: 1.2999
# Early stopping, best iteration is:
# [205]	training's rmse: 0.715565	valid_1's rmse: 1.29958
# Site Id: 13 , Meter: 1 , Fold: 4 , RMSE: 1.2964028786923063
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.782892	valid_1's rmse: 1.41815
# Early stopping, best iteration is:
# [87]	training's rmse: 0.79889	valid_1's rmse: 1.41538
# Site Id: 13 , Meter: 1 , Fold: 5 , RMSE: 1.4395758941984687
# Site Id: 13 , Meter: 1 , CV RMSE: 2.0659140687150677
#
# 5 fold CV for site_id: 13 for meter: 2
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.06407	valid_1's rmse: 1.80798
# [200]	training's rmse: 0.941768	valid_1's rmse: 1.80048
# Early stopping, best iteration is:
# [204]	training's rmse: 0.938925	valid_1's rmse: 1.80022
# Site Id: 13 , Meter: 2 , Fold: 1 , RMSE: 1.7966483914952045
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.17322	valid_1's rmse: 1.54888
# Early stopping, best iteration is:
# [157]	training's rmse: 1.10579	valid_1's rmse: 1.54183
# Site Id: 13 , Meter: 2 , Fold: 2 , RMSE: 1.6960838251309072
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.15012	valid_1's rmse: 1.51897
# Early stopping, best iteration is:
# [169]	training's rmse: 1.0774	valid_1's rmse: 1.51041
# Site Id: 13 , Meter: 2 , Fold: 3 , RMSE: 1.5227447130377427
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.12737	valid_1's rmse: 1.66084
# Early stopping, best iteration is:
# [83]	training's rmse: 1.15557	valid_1's rmse: 1.65698
# Site Id: 13 , Meter: 2 , Fold: 4 , RMSE: 1.6618330487883206
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.15393	valid_1's rmse: 1.71743
# Early stopping, best iteration is:
# [89]	training's rmse: 1.17144	valid_1's rmse: 1.71192
# Site Id: 13 , Meter: 2 , Fold: 5 , RMSE: 1.709657595030129
#
# Site Id: 13 , Meter: 2 , CV RMSE: 2.997007604990662
#
# 5 fold CV for site_id: 13 for meter: 3
# 5 fold CV for site_id: 14 for meter: 0
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.648434	valid_1's rmse: 0.988136
# Early stopping, best iteration is:
# [120]	training's rmse: 0.617103	valid_1's rmse: 0.982775
# Site Id: 14 , Meter: 0 , Fold: 1 , RMSE: 0.9834428784746745
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.65809	valid_1's rmse: 0.898761
# Early stopping, best iteration is:
# [120]	training's rmse: 0.629181	valid_1's rmse: 0.894731
# Site Id: 14 , Meter: 0 , Fold: 2 , RMSE: 0.8832192401451139
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.659429	valid_1's rmse: 0.992992
# [200]	training's rmse: 0.559862	valid_1's rmse: 0.971268
# Early stopping, best iteration is:
# [235]	training's rmse: 0.53602	valid_1's rmse: 0.969295
# Site Id: 14 , Meter: 0 , Fold: 3 , RMSE: 0.9353803657233132
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.673677	valid_1's rmse: 0.978508
# [200]	training's rmse: 0.55755	valid_1's rmse: 0.937444
# Early stopping, best iteration is:
# [245]	training's rmse: 0.528463	valid_1's rmse: 0.932407
# Site Id: 14 , Meter: 0 , Fold: 4 , RMSE: 1.048065988691768
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.696272	valid_1's rmse: 0.881735
# [200]	training's rmse: 0.568116	valid_1's rmse: 0.86641
# Early stopping, best iteration is:
# [217]	training's rmse: 0.557857	valid_1's rmse: 0.866039
# Site Id: 14 , Meter: 0 , Fold: 5 , RMSE: 0.8646631190250341
#
# Site Id: 14 , Meter: 0 , CV RMSE: 1.855221197340101
#
# 5 fold CV for site_id: 14 for meter: 1
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.38477	valid_1's rmse: 1.6257
# Early stopping, best iteration is:
# [176]	training's rmse: 1.29254	valid_1's rmse: 1.59938
# Site Id: 14 , Meter: 1 , Fold: 1 , RMSE: 1.7452194311627829
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.26803	valid_1's rmse: 1.51433
# Early stopping, best iteration is:
# [140]	training's rmse: 1.22231	valid_1's rmse: 1.50926
# Site Id: 14 , Meter: 1 , Fold: 2 , RMSE: 1.5131218172857386
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.23836	valid_1's rmse: 1.8635
# Early stopping, best iteration is:
# [140]	training's rmse: 1.19313	valid_1's rmse: 1.85969
# Site Id: 14 , Meter: 1 , Fold: 3 , RMSE: 1.8277510651399278
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [50]	training's rmse: 1.41805	valid_1's rmse: 1.74314
# Site Id: 14 , Meter: 1 , Fold: 4 , RMSE: 1.770141348017865
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.2895	valid_1's rmse: 1.63311
# [200]	training's rmse: 1.19213	valid_1's rmse: 1.60916
# Early stopping, best iteration is:
# [204]	training's rmse: 1.18957	valid_1's rmse: 1.60831
# Site Id: 14 , Meter: 1 , Fold: 5 , RMSE: 1.6061721285455355
#
# Site Id: 14 , Meter: 1 , CV RMSE: 2.6176195599982077
#
# 5 fold CV for site_id: 14 for meter: 2
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [51]	training's rmse: 1.34461	valid_1's rmse: 1.53323
# Site Id: 14 , Meter: 2 , Fold: 1 , RMSE: 1.536914882250112
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.16625	valid_1's rmse: 1.22819
# Early stopping, best iteration is:
# [120]	training's rmse: 1.14142	valid_1's rmse: 1.21721
# Site Id: 14 , Meter: 2 , Fold: 2 , RMSE: 1.223725698174765
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.10234	valid_1's rmse: 1.41502
# [200]	training's rmse: 1.02466	valid_1's rmse: 1.4021
# Early stopping, best iteration is:
# [242]	training's rmse: 0.999587	valid_1's rmse: 1.39665
# Site Id: 14 , Meter: 2 , Fold: 3 , RMSE: 1.3966937736731386
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.09401	valid_1's rmse: 1.51632
# [200]	training's rmse: 0.997641	valid_1's rmse: 1.43148
# [300]	training's rmse: 0.943566	valid_1's rmse: 1.40212
# [400]	training's rmse: 0.901896	valid_1's rmse: 1.37411
# [500]	training's rmse: 0.871493	valid_1's rmse: 1.36359
# [600]	training's rmse: 0.847239	valid_1's rmse: 1.35535
# [700]	training's rmse: 0.825436	valid_1's rmse: 1.34147
# Early stopping, best iteration is:
# [699]	training's rmse: 0.825588	valid_1's rmse: 1.34147
# Site Id: 14 , Meter: 2 , Fold: 4 , RMSE: 1.4994824015964199
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.07744	valid_1's rmse: 1.48802
# Early stopping, best iteration is:
# [102]	training's rmse: 1.07354	valid_1's rmse: 1.48776
# Site Id: 14 , Meter: 2 , Fold: 5 , RMSE: 1.5054866888423943
#
# Site Id: 14 , Meter: 2 , CV RMSE: 2.5858425776325014
#
# 5 fold CV for site_id: 14 for meter: 3
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.39651	valid_1's rmse: 2.16933
# Early stopping, best iteration is:
# [99]	training's rmse: 1.39777	valid_1's rmse: 2.16921
# Site Id: 14 , Meter: 3 , Fold: 1 , RMSE: 2.163223126595476
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.44642	valid_1's rmse: 1.83092
# Early stopping, best iteration is:
# [80]	training's rmse: 1.48088	valid_1's rmse: 1.82585
# Site Id: 14 , Meter: 3 , Fold: 2 , RMSE: 1.8423172328153739
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.51737	valid_1's rmse: 1.42321
# [200]	training's rmse: 1.4202	valid_1's rmse: 1.41664
# [300]	training's rmse: 1.35937	valid_1's rmse: 1.4131
# Early stopping, best iteration is:
# [298]	training's rmse: 1.36034	valid_1's rmse: 1.41248
# Site Id: 14 , Meter: 3 , Fold: 3 , RMSE: 1.3968973179700546
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.45391	valid_1's rmse: 1.62579
# Early stopping, best iteration is:
# [140]	training's rmse: 1.41545	valid_1's rmse: 1.60299
# Site Id: 14 , Meter: 3 , Fold: 4 , RMSE: 1.616540823367497
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 1.4451	valid_1's rmse: 1.81903
# [200]	training's rmse: 1.36181	valid_1's rmse: 1.80686
# Early stopping, best iteration is:
# [183]	training's rmse: 1.37354	valid_1's rmse: 1.80633
# Site Id: 14 , Meter: 3 , Fold: 5 , RMSE: 1.8097001885660333
#
# Site Id: 14 , Meter: 3 , CV RMSE: 2.586901188949355
#
# 5 fold CV for site_id: 15 for meter: 0
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [48]	training's rmse: 0.237789	valid_1's rmse: 0.679494
# Site Id: 15 , Meter: 0 , Fold: 1 , RMSE: 0.6795187411363244
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [69]	training's rmse: 0.276767	valid_1's rmse: 0.179061
# Site Id: 15 , Meter: 0 , Fold: 2 , RMSE: 0.1795350727672336
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.225107	valid_1's rmse: 0.302003
# Early stopping, best iteration is:
# [179]	training's rmse: 0.19533	valid_1's rmse: 0.298417
# Site Id: 15 , Meter: 0 , Fold: 3 , RMSE: 0.29798374852354637
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.240324	valid_1's rmse: 0.300227
# [200]	training's rmse: 0.203353	valid_1's rmse: 0.291576
# [300]	training's rmse: 0.184526	valid_1's rmse: 0.288553
# [400]	training's rmse: 0.174471	valid_1's rmse: 0.28757
# [500]	training's rmse: 0.166949	valid_1's rmse: 0.286906
# Early stopping, best iteration is:
# [492]	training's rmse: 0.167564	valid_1's rmse: 0.286838
# Site Id: 15 , Meter: 0 , Fold: 4 , RMSE: 0.28887365511180213
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.245243	valid_1's rmse: 0.311753
# Early stopping, best iteration is:
# [129]	training's rmse: 0.230525	valid_1's rmse: 0.310535
# Site Id: 15 , Meter: 0 , Fold: 5 , RMSE: 0.30942449473438577
#
# Site Id: 15 , Meter: 0 , CV RMSE: 1.8888049845257884
#
# 5 fold CV for site_id: 15 for meter: 1
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.351898	valid_1's rmse: 0.91707
# [200]	training's rmse: 0.319517	valid_1's rmse: 0.904814
# Early stopping, best iteration is:
# [205]	training's rmse: 0.318317	valid_1's rmse: 0.904608
# Site Id: 15 , Meter: 1 , Fold: 1 , RMSE: 0.9173445150301734
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.480301	valid_1's rmse: 0.5907
# Early stopping, best iteration is:
# [84]	training's rmse: 0.496589	valid_1's rmse: 0.590646
# Site Id: 15 , Meter: 1 , Fold: 2 , RMSE: 0.5871930004226872
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [43]	training's rmse: 0.552483	valid_1's rmse: 0.68302
# Site Id: 15 , Meter: 1 , Fold: 3 , RMSE: 0.7022779610297752
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.449969	valid_1's rmse: 0.887102
# [200]	training's rmse: 0.408898	valid_1's rmse: 0.871857
# Early stopping, best iteration is:
# [275]	training's rmse: 0.393373	valid_1's rmse: 0.865739
# Site Id: 15 , Meter: 1 , Fold: 4 , RMSE: 0.8680458752274465
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.464681	valid_1's rmse: 0.721841
# [200]	training's rmse: 0.421591	valid_1's rmse: 0.711753
# [300]	training's rmse: 0.401116	valid_1's rmse: 0.706731
# Early stopping, best iteration is:
# [317]	training's rmse: 0.398754	valid_1's rmse: 0.706109
# Site Id: 15 , Meter: 1 , Fold: 5 , RMSE: 0.7027654420893115
#
# Site Id: 15 , Meter: 1 , CV RMSE: 1.5558341739406458
#
# 5 fold CV for site_id: 15 for meter: 2
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.883972	valid_1's rmse: 1.32691
# Early stopping, best iteration is:
# [169]	training's rmse: 0.835913	valid_1's rmse: 1.31589
# Site Id: 15 , Meter: 2 , Fold: 1 , RMSE: 1.3120188899060174
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.822464	valid_1's rmse: 1.06746
# Early stopping, best iteration is:
# [128]	training's rmse: 0.806065	valid_1's rmse: 1.06473
# Site Id: 15 , Meter: 2 , Fold: 2 , RMSE: 1.0499454168014835
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.87898	valid_1's rmse: 0.756568
# Early stopping, best iteration is:
# [128]	training's rmse: 0.862124	valid_1's rmse: 0.752484
# Site Id: 15 , Meter: 2 , Fold: 3 , RMSE: 0.7359843268436456
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.822676	valid_1's rmse: 1.00413
# [200]	training's rmse: 0.783185	valid_1's rmse: 0.985124
# [300]	training's rmse: 0.758594	valid_1's rmse: 0.978583
# [400]	training's rmse: 0.739953	valid_1's rmse: 0.972788
# Early stopping, best iteration is:
# [469]	training's rmse: 0.728832	valid_1's rmse: 0.969443
# Site Id: 15 , Meter: 2 , Fold: 4 , RMSE: 0.9835423683943393
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.820846	valid_1's rmse: 1.10345
# [200]	training's rmse: 0.784493	valid_1's rmse: 1.0951
# [300]	training's rmse: 0.762419	valid_1's rmse: 1.09044
# [400]	training's rmse: 0.746162	valid_1's rmse: 1.08676
# Early stopping, best iteration is:
# [396]	training's rmse: 0.74692	valid_1's rmse: 1.08639
# Site Id: 15 , Meter: 2 , Fold: 5 , RMSE: 1.085220111302155
#
# Site Id: 15 , Meter: 2 , CV RMSE: 2.4946575310439094
#
# 5 fold CV for site_id: 15 for meter: 3
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [3]	training's rmse: 0.450562	valid_1's rmse: 0.783385
# Site Id: 15 , Meter: 3 , Fold: 1 , RMSE: 0.7833853279984346
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.301563	valid_1's rmse: 0.323519
# Early stopping, best iteration is:
# [108]	training's rmse: 0.295993	valid_1's rmse: 0.323027
# Site Id: 15 , Meter: 3 , Fold: 2 , RMSE: 0.32699326406968965
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [45]	training's rmse: 0.338098	valid_1's rmse: 2.56879
# Site Id: 15 , Meter: 3 , Fold: 3 , RMSE: 2.568792227652836
# Training until validation scores don't improve for 20 rounds
# Early stopping, best iteration is:
# [44]	training's rmse: 0.448011	valid_1's rmse: 0.723044
# Site Id: 15 , Meter: 3 , Fold: 4 , RMSE: 0.7230435307605473
# Training until validation scores don't improve for 20 rounds
# [100]	training's rmse: 0.369591	valid_1's rmse: 0.473922
# Early stopping, best iteration is:
# [116]	training's rmse: 0.359199	valid_1's rmse: 0.471574
# Site Id: 15 , Meter: 3 , Fold: 5 , RMSE: 0.4715736135290024
#
# Site Id: 15 , Meter: 3 , CV RMSE: 2.4625240592474626

# %%
pd.DataFrame.from_dict(cv_scores)
# Out:
#    (site_id, meter)  cv_score
# 0            (0, 0)  0.410399
# 1            (0, 1)  1.623438
# 2            (1, 0)  0.479225
# 3            (1, 3)  1.943374
# 4            (2, 0)  0.479664
# 5            (2, 1)  1.154631
# 6            (2, 3)  0.956113
# 7            (3, 0)  0.408615
# 8            (4, 0)  0.260476
# 9            (5, 0)  0.674510
# 10           (6, 0)  0.369023
# 11           (6, 1)  1.691649
# 12           (6, 2)  1.732432
# 13           (7, 0)  1.958645
# 14           (7, 1)  1.672285
# 15           (7, 2)  1.600593
# 16           (7, 3)  2.047935
# 17           (8, 0)  0.647797
# 18           (9, 0)  0.611244
# 19           (9, 1)  0.944127
# 20           (9, 2)  1.237253
# 21          (10, 0)  0.513034
# 22          (10, 1)  1.228855
# 23          (10, 3)  2.596825
# 24          (11, 0)  0.516606
# 25          (11, 1)  0.908556
# 26          (11, 3)  1.085744
# 27          (12, 0)  0.405734
# 28          (13, 0)  0.486563
# 29          (13, 1)  1.425640
# 30          (13, 2)  1.677394
# 31          (14, 0)  0.942954
# 32          (14, 1)  1.692481
# 33          (14, 2)  1.432461
# 34          (14, 3)  1.765736
# 35          (15, 0)  0.351067
# 36          (15, 1)  0.755525
# 37          (15, 2)  1.033342
# 38          (15, 3)  0.974758

# %%
pd.DataFrame.from_dict(cv_scores)
# Out:
#    (site_id, meter)  cv_score
# 0            (0, 0)  0.410399
# 1            (0, 1)  1.623438
# 2            (1, 0)  0.479225
# 3            (1, 3)  1.943374
# 4            (2, 0)  0.479664
# 5            (2, 1)  1.154631
# 6            (2, 3)  0.956113
# 7            (3, 0)  0.408615
# 8            (4, 0)  0.260476
# 9            (5, 0)  0.675664
# 10           (6, 0)  0.369023
# 11           (6, 1)  1.691649
# 12           (6, 2)  1.732432
# 13           (7, 0)  1.958645
# 14           (7, 1)  1.672285
# 15           (7, 2)  1.600593
# 16           (7, 3)  2.047935
# 17           (8, 0)  0.647797
# 18           (9, 0)  0.611244
# 19           (9, 1)  0.944259
# 20           (9, 2)  1.237253
# 21          (10, 0)  0.513034
# 22          (10, 1)  1.228855
# 23          (10, 3)  2.596825
# 24          (11, 0)  0.516606
# 25          (11, 1)  0.908556
# 26          (11, 3)  1.085744
# 27          (12, 0)  0.405734
# 28          (13, 0)  0.486563
# 29          (13, 1)  1.425640
# 30          (13, 2)  1.677394
# 31          (14, 0)  0.942954
# 32          (14, 1)  1.692481
# 33          (14, 2)  1.432461
# 34          (14, 3)  1.765736
# 35          (15, 0)  0.351067
# 36          (15, 1)  0.755525
# 37          (15, 2)  1.033342
# 38          (15, 3)  0.974758

# %%
del df_train, X_train_site, y_train_site, X_train, y_train, dtrain, X_valid, y_valid, dvalid, y_pred_train_site, y_pred_valid, rmse, score, cv_scores
gc.collect()
# Out:
# 85

# %% [markdown]
# ## Scoring on test data
# The test data for each site is scored individually using the 3 models, one from each fold. The final prediction is the average of the 3 models.

# %%
weather_test = create_lag_features(weather_test, 18)
weather_test.drop(["air_temperature", "cloud_coverage", "dew_temperature", "precip_depth_1_hr"], axis=1, inplace=True)

# %%
df_test_sites = []

for site_id in tqdm(range(16), desc="site_id"):
    for meter in range(4):
        print("Preparing test data for (site_id, meter)", (site_id, meter))

        X_test_site = df_test[(df_test.site_id==site_id) & (df_test.meter==meter)]
        if X_test_site.shape[0] == 0:
            continue
        weather_test_site = weather_test[weather_test.site_id==site_id]
    
        X_test_site = X_test_site.merge(weather_test_site, on=["site_id", "timestamp"], how="left")
    
        row_ids_site = X_test_site.row_id

        X_test_site = X_test_site.loc[:, all_features]
        y_pred_test_site = np.zeros(X_test_site.shape[0])

        print("Scoring for site_id", site_id, "for meter", meter)    
        """
        for fold in range(cv):
            model_lgb = models[(site_id, meter)][fold]
            y_pred_test_site += model_lgb.predict(X_test_site, num_iteration=model_lgb.best_iteration) / cv
            gc.collect()
        """
        model_lgb = models[(site_id, meter)]
        y_pred_test_site = model_lgb.predict(X_test_site)
        
        df_test_site = pd.DataFrame({"row_id": row_ids_site, "meter_reading": y_pred_test_site})
        df_test_sites.append(df_test_site)
    
        print("Scoring for site_id", site_id, "for meter", meter, "completed\n")
        gc.collect()
# Out:
# HBox(children=(IntProgress(value=0, description='site_id', max=16, style=ProgressStyle(description_width='init…
# Preparing test data for (site_id, meter) (0, 0)
# Scoring for site_id 0 for meter 0
# Scoring for site_id 0 for meter 0 completed
#
# Preparing test data for (site_id, meter) (0, 1)
# Scoring for site_id 0 for meter 1
# Scoring for site_id 0 for meter 1 completed
#
# Preparing test data for (site_id, meter) (0, 2)
# Preparing test data for (site_id, meter) (0, 3)
# Preparing test data for (site_id, meter) (1, 0)
# Scoring for site_id 1 for meter 0
# Scoring for site_id 1 for meter 0 completed
#
# Preparing test data for (site_id, meter) (1, 1)
# Preparing test data for (site_id, meter) (1, 2)
# Preparing test data for (site_id, meter) (1, 3)
# Scoring for site_id 1 for meter 3
# Scoring for site_id 1 for meter 3 completed
#
# Preparing test data for (site_id, meter) (2, 0)
# Scoring for site_id 2 for meter 0
# Scoring for site_id 2 for meter 0 completed
#
# Preparing test data for (site_id, meter) (2, 1)
# Scoring for site_id 2 for meter 1
# Scoring for site_id 2 for meter 1 completed
#
# Preparing test data for (site_id, meter) (2, 2)
# Preparing test data for (site_id, meter) (2, 3)
# Scoring for site_id 2 for meter 3
# Scoring for site_id 2 for meter 3 completed
#
# Preparing test data for (site_id, meter) (3, 0)
# Scoring for site_id 3 for meter 0
# Scoring for site_id 3 for meter 0 completed
#
# Preparing test data for (site_id, meter) (3, 1)
# Preparing test data for (site_id, meter) (3, 2)
# Preparing test data for (site_id, meter) (3, 3)
# Preparing test data for (site_id, meter) (4, 0)
# Scoring for site_id 4 for meter 0
# Scoring for site_id 4 for meter 0 completed
#
# Preparing test data for (site_id, meter) (4, 1)
# Preparing test data for (site_id, meter) (4, 2)
# Preparing test data for (site_id, meter) (4, 3)
# Preparing test data for (site_id, meter) (5, 0)
# Scoring for site_id 5 for meter 0
# Scoring for site_id 5 for meter 0 completed
#
# Preparing test data for (site_id, meter) (5, 1)
# Preparing test data for (site_id, meter) (5, 2)
# Preparing test data for (site_id, meter) (5, 3)
# Preparing test data for (site_id, meter) (6, 0)
# Scoring for site_id 6 for meter 0
# Scoring for site_id 6 for meter 0 completed
#
# Preparing test data for (site_id, meter) (6, 1)
# Scoring for site_id 6 for meter 1
# Scoring for site_id 6 for meter 1 completed
#
# Preparing test data for (site_id, meter) (6, 2)
# Scoring for site_id 6 for meter 2
# Scoring for site_id 6 for meter 2 completed
#
# Preparing test data for (site_id, meter) (6, 3)
# Preparing test data for (site_id, meter) (7, 0)
# Scoring for site_id 7 for meter 0
# Scoring for site_id 7 for meter 0 completed
#
# Preparing test data for (site_id, meter) (7, 1)
# Scoring for site_id 7 for meter 1
# Scoring for site_id 7 for meter 1 completed
#
# Preparing test data for (site_id, meter) (7, 2)
# Scoring for site_id 7 for meter 2
# Scoring for site_id 7 for meter 2 completed
#
# Preparing test data for (site_id, meter) (7, 3)
# Scoring for site_id 7 for meter 3
# Scoring for site_id 7 for meter 3 completed
#
# Preparing test data for (site_id, meter) (8, 0)
# Scoring for site_id 8 for meter 0
# Scoring for site_id 8 for meter 0 completed
#
# Preparing test data for (site_id, meter) (8, 1)
# Preparing test data for (site_id, meter) (8, 2)
# Preparing test data for (site_id, meter) (8, 3)
# Preparing test data for (site_id, meter) (9, 0)
# Scoring for site_id 9 for meter 0
# Scoring for site_id 9 for meter 0 completed
#
# Preparing test data for (site_id, meter) (9, 1)
# Scoring for site_id 9 for meter 1
# Scoring for site_id 9 for meter 1 completed
#
# Preparing test data for (site_id, meter) (9, 2)
# Scoring for site_id 9 for meter 2
# Scoring for site_id 9 for meter 2 completed
#
# Preparing test data for (site_id, meter) (9, 3)
# Preparing test data for (site_id, meter) (10, 0)
# Scoring for site_id 10 for meter 0
# Scoring for site_id 10 for meter 0 completed
#
# Preparing test data for (site_id, meter) (10, 1)
# Scoring for site_id 10 for meter 1
# Scoring for site_id 10 for meter 1 completed
#
# Preparing test data for (site_id, meter) (10, 2)
# Preparing test data for (site_id, meter) (10, 3)
# Scoring for site_id 10 for meter 3
# Scoring for site_id 10 for meter 3 completed
#
# Preparing test data for (site_id, meter) (11, 0)
# Scoring for site_id 11 for meter 0
# Scoring for site_id 11 for meter 0 completed
#
# Preparing test data for (site_id, meter) (11, 1)
# Scoring for site_id 11 for meter 1
# Scoring for site_id 11 for meter 1 completed
#
# Preparing test data for (site_id, meter) (11, 2)
# Preparing test data for (site_id, meter) (11, 3)
# Scoring for site_id 11 for meter 3
# Scoring for site_id 11 for meter 3 completed
#
# Preparing test data for (site_id, meter) (12, 0)
# Scoring for site_id 12 for meter 0
# Scoring for site_id 12 for meter 0 completed
#
# Preparing test data for (site_id, meter) (12, 1)
# Preparing test data for (site_id, meter) (12, 2)
# Preparing test data for (site_id, meter) (12, 3)
# Preparing test data for (site_id, meter) (13, 0)
# Scoring for site_id 13 for meter 0
# Scoring for site_id 13 for meter 0 completed
#
# Preparing test data for (site_id, meter) (13, 1)
# Scoring for site_id 13 for meter 1
# Scoring for site_id 13 for meter 1 completed
#
# Preparing test data for (site_id, meter) (13, 2)
# Scoring for site_id 13 for meter 2
# Scoring for site_id 13 for meter 2 completed
#
# Preparing test data for (site_id, meter) (13, 3)
# Preparing test data for (site_id, meter) (14, 0)
# Scoring for site_id 14 for meter 0
# Scoring for site_id 14 for meter 0 completed
#
# Preparing test data for (site_id, meter) (14, 1)
# Scoring for site_id 14 for meter 1
# Scoring for site_id 14 for meter 1 completed
#
# Preparing test data for (site_id, meter) (14, 2)
# Scoring for site_id 14 for meter 2
# Scoring for site_id 14 for meter 2 completed
#
# Preparing test data for (site_id, meter) (14, 3)
# Scoring for site_id 14 for meter 3
# Scoring for site_id 14 for meter 3 completed
#
# Preparing test data for (site_id, meter) (15, 0)
# Scoring for site_id 15 for meter 0
# Scoring for site_id 15 for meter 0 completed
#
# Preparing test data for (site_id, meter) (15, 1)
# Scoring for site_id 15 for meter 1
# Scoring for site_id 15 for meter 1 completed
#
# Preparing test data for (site_id, meter) (15, 2)
# Scoring for site_id 15 for meter 2
# Scoring for site_id 15 for meter 2 completed
#
# Preparing test data for (site_id, meter) (15, 3)
# Scoring for site_id 15 for meter 3
# Scoring for site_id 15 for meter 3 completed

# %% [markdown]
# ## Submission
# Preparing final file for submission.

# %%
today = str(datetime.date.today())

# %%
submit = pd.concat(df_test_sites)
submit.meter_reading = np.clip(np.expm1(submit.meter_reading), 0, a_max=None)
submit = submit.sort_values('row_id')
submit.to_csv(f"submission_noleak_{today}_2.csv", index=False)

# %%
## adding leak
leak0 = pd.read_csv("./ashrae-leak-data/site0.csv")
leak1 = pd.read_csv("./ashrae-leak-data/site1.csv")
leak2 = pd.read_csv("./ashrae-leak-data/site2.csv")
leak4 = pd.read_csv("./ashrae-leak-data/site4.csv")
leak15 = pd.read_csv("./ashrae-leak-data/site15.csv")

leak = pd.concat([leak0, leak1, leak2, leak4, leak15])

del leak0, leak1, leak2, leak4, leak15
gc.collect()

test = pd.read_csv(path_test)
test = test[test.building_id.isin(leak.building_id.unique())]

leak = leak.merge(test, on=["building_id", "meter", "timestamp"])

del test
gc.collect()

submit = submit.merge(leak[["row_id", "meter_reading_scraped"]], on=["row_id"], how="left")
submit.loc[submit.meter_reading_scraped.notnull(), "meter_reading"] = submit.loc[submit.meter_reading_scraped.notnull(), "meter_reading_scraped"] 
submit.drop(["meter_reading_scraped"], axis=1, inplace=True)

submit.to_csv(f"submission_{today}.csv", index=False)
